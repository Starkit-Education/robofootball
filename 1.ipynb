# %%
# !git clone https://github.com/ar0usel/robofootball.git
# Out:
# fatal: destination path 'robofootball' already exists and is not an empty directory.

# %%
cd robofootball
# Out:
# /content/robofootball

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git log --oneline --graph
# Out:
# *   f760a38 (HEAD -> main, origin/main, origin/HEAD) Merge branch 'Starkit-Education:main' into main
# |\
# | * 4f41407 Update README.md
# | * 17893f1 Added: first homework
# * |   ec08a6b Merge pull request #1 from ar0usel/test
# |\ \
# | * \   9b6aa88 Merge branch 'main' into test
# | |\ \
# | |/ /
# |/| |
# * | | 98645ab Update README.md
# | * | 497fc76 Update README.md
# |/ /
# * | 5afbd7c Update README.md
# |/
# * ccb168c Added: first seminar
# * 5405d27 Initial commit

# %%
# !git remote add origin-psk https://abramov1309:{token}@github.com/abramov1309/robofootball.git
# Out:
# fatal: remote origin-psk already exists.
